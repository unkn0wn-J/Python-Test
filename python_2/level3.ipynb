# %% [markdown]
# 안녕하세요.<br><br>
# 수강생 여러분~!
#
# "Challenge : Chapter05 ~ 08 문제풀기"는 잘 풀어보셨나요?
#
#
# 너~~무 어려웠어요! 하는 분들을 위해 만들어봤습니다!
#
# 문제 도장깨기 !!!!!
#
# 차근차근 풀어나가면 파이썬 정복 가능입니다!
#
# 화이팅 !
#
#
# Chapter05~08의 수업 내용을 바탕으로 아래 문제를 풀어주시면 됩니다.
#
# <br>
#
# [**답변 입력 방법**]
#
# 문제 아래에 있는 코드 입력창에 정답코드를 작성하신 후  __▷ 버튼을 클릭해 코드를 실행__ 해보세요<br>
# <br>

# %% [markdown]
# -----

# %% [markdown]
# <br>
#
# __[문제1]__
#
# 미션 부수기 챌린지
#
# 다음 미션을 차례대로 부숴주세요.
#
# <br>
#
# __미션__
# - x에 5를 할당하고, y에는 10을 할당
# - x의 값을 제곱하고, 그 값을 z에 할당
# - y의 값을 2로 나눈 후, 그 값을 a에 할당
# - a와 z를 더한 값을 b에 할당
# - b의 값이 x와 같은지 출력
# -  b와 a를 문자열로 변환하여 합친 결과를 출력
#
#
# <br>

# %%
"""print(str(b) + str(a)) << 이 때 str 넣지 못했음 정답지 보고 이해 완료"""

x=5
y=10
z= x**2
a= y/2
b = a + z
asd = b == x

print(asd)
print(str(b) + str(a))
# Out:
# False
# 30.05.0

# %% [markdown]
# <br>
#
# __[문제2]__
#
# 변수 num에 "45.67" 이라는 문자열을 할당하고,
#
# 파이썬 나라에서 돌다리를 건너려고 합니다.
#
# 이 돌다리는 반드시 두드려 보고 건너야 합니다.
#
# 미션을 해결하면 자동으로 단단한 돌다리인지 확인 됩니다!
#
# 아래의 미션을 확인하고 돌다리를 건너주세요!
#
# <br>
#
# __미션__
# - 문자열 할당 (num)
# - 소수점 포함 숫자로 출력
# - 정수만 출력
#
# <br>

# %%
""" 
내 정답 정답지 보고 이해 완료
num = "45.67"

print(int(num))
print(float(num))
"""


num = "45.67"

print(float(num))
print(int(float(num)))
# Out:
# 45.67
# 45

# %% [markdown]
# <br>
#
# __[문제3]__
#
# 첫 번째 공백을 기준으로 앞부분만 추출해주세요!
#
# <br>
#
# __text = "Hello World Python"__

# %%
text = "Hello World Python"

print(text.split( )[0])
# Out:
# Hello

# %% [markdown]
# <br>__[문제4]__
#
# 문자열 "PythonProgramming" 이 주어졌을 때, 다음 미션을 해결해주세요!
#
# <br>
#
# __미션__
# - "Python"을 출력
# - "Programming" 출력
# - "Pyg" 출력
# - "in" 출력

# %%
"""Pyg 출력 코드 못적음 정답지 보고 이해 완료"""


text = "PythonProgramming"


print(text[0:6])
print(text[6:17])
print(text[14:16])
# Out:
# Python
# Programming
# in

# %% [markdown]
# __[문제5]__
#
# 해외로 편지를 보냅니다.
#
# 영어를 알파벳만 알기 때문에 아는 것만 적어 보내려고 합니다.
#
# 근데 중간에 오타가 발생해버렸네요! 문자열의 일부를 바꿔 올바르게 고쳐 주세요. (소문자)
#
# <br>
#
# __word = "abcXYZgh"__

# %%
"""시작도 못함 replace 처음 듣는 것 같음 질문도 좀 이상한 거 같음 올바르게가 XYZ > xyz 인지 알파펫을 순서대로 하라는 뜻인지 모르겠음"""

word = "abcXYZgh"

# "XYZ"를 소문자 "def"로 변경
word = word.replace("XYZ", "def")

print(word)  # 출력: abcdefgh
# Out:
# False

# %% [markdown]
# __[문제6]__
#
# 창의성, 시장성, 안정성, 수익성에 대한 각각의 평가 중 아래 기준에 부합하지 못하면 창업지원을 받을 수 없습니다.
#
# - 수익성 60점 이상
# - 창의성과 시장성 50점 이상
# - 시장성과 수익성을 더한 값의 절반이 안정성 보다 높아야 함
#
#
# 다음 점수가 입력되었을때 창업 지원이 가능한지 여부를 True 또는 False로 출력해주세요.
#
# ---
#
# 창의성 : 62
# 시장성 : 71
# 안정성 : 68
# 수익성 : 66
# <br>
#
# * 참고
# (creativity ,
# marketability ,
# stability ,
# profitability )
#
# <br>
#
# __Tips__
# * 비교 연산자와 논리 연산자의 결과를 고려해보아요

# %%
"""대충 구성은 맞출 수 있음 다만 and 대신 , 를 쓴다던가 하는 그런 디테일이 없음 정답지 보고 이해 완료"""


creativity=62 #창의성
marketability=71 #시작성
stability=68 #안정성
profitability=66 #수익성

print(profitability>=60 and creativity>=50 and marketability>=50 and  (marketability + profitability) / 2 > stability)
# Out:
# True
